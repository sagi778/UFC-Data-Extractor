# %%
# %run web_scrape_func_def.ipynb
# Out:
# > file management func:
#
#     get_content(directory)
#     get_last_update(file_path)
#
# > Updating lists func:
#
#     get_participants(event_link)
#
# > fighters_stats_scrape func:
#
#     get_xml(url, data_type='xml', headers = {'User-Agent':'Moz...}) # Return web page data in .xml format.
#     get_links(url)
#     get_fighter_data(url) # Retrive data as list
#     get_current_date()
#
# > matches_stats_web_scrape func:
#
#     get_event_date(xml)
#     get_event_data(event_link)
#     get_later_date(date1, date2)
#
# > upcoming_web_scrape func:
#
#     get_upcoming_event_url(xml)
#     get_upcoming_event_data(upcoming_event_url)
#
# > fighters_stats_full_update func:
#
#     get_fighters_links(page_url)
#
# > draftking_odds func:
#
#     get_table_odds(table)
#     get_odds(data, fighter, opponent)

# %% [markdown]
# # Main()

# %%
URL = 'https://sportsbook.draftkings.com/leagues/mma/ufc'
CARDS_PATH = '../cards/'

# %%
xml = get_xml(url=URL, data_type='html')
tables = xml.find_all('table')

data = pd.DataFrame(columns=['fighter','fighter_odds','opponent','opponent_odds'])
for table in xml.find_all('table'):
    #print(table)
    try:
        data = pd.concat([data,get_table_odds(table=table)])
    except: 
        print
        continue    
    #t.append(get_table_odds(table=table))
    
data = data.reset_index(drop=True)
data
# Out:
#                   fighter fighter_odds                opponent opponent_odds
# 0            Kamuela Kirk         +165        Esteban Ribovics          −195
# 1            Shannon Ross         +180    Jesus Santos Aguilar          −210
# 2           Vitor Petrino         −260         Marcin Prachnio          +220
# 3             Jimmy Crute         −110        Alonzo Menifield          −110
# 4         Yazmin Jauregui         −410            Denise Gomes          +330
# 5              Sean Brady         −115    Jack Della Maddalena          −105
# 6           Robbie Lawler         +225              Niko Price          −265
# 7               Bo Nickal        −1250            Tresean Gore          +800
# 8            Jalin Turner         −250              Dan Hooker          +210
# 9        Robert Whittaker         −380       Dricus Du Plessis          +310
# 10         Brandon Moreno         −175       Alexandre Pantoja          +150
# 11  Alexander Volkanovski         −410          Yair Rodriguez          +330
# 12         Michael Chiesa         +150           Kevin Holland          −175
# 13          Derrick Lewis         −110  Marcos Rogerio De Lima          −110
# 14       Stephen Thompson         −215          Michel Pereira          +185
# 15            Paulo Costa         +105         Ikram Aliskerov          −125
# 16          Tony Ferguson         +275             Bobby Green          −330
# 17         Jan Blachowicz         −150            Alex Pereira          +130
# 18         Dustin Poirier         −130          Justin Gaethje          +110
# 19        Ikram Aliskerov         −115             Paulo Costa          −105
# 20          Kevin Holland         −175          Michael Chiesa          +150
# 21           Henry Cejudo         −330             Marlon Vera          +275
# 22      Aljamain Sterling         −255           Sean O'Malley          +215
# 23           Alexa Grasso         +195    Valentina Shevchenko          −230
# 24         Curtis Blaydes         +125         Jailton Almeida          −145
# 25        Khamzat Chimaev         −350             Paulo Costa          +290
# 26              Jon Jones         −320            Stipe Miocic          +265
# 27           Leon Edwards         −110         Colby Covington          −110
# 28         Conor McGregor         −110        Michael Chandler          −110
# 29        Islam Makhachev         −285        Charles Oliveira          +240

# %%
#example use
get_odds(data=data, fighter='Marlon Vera', opponent='Henry Cejudo')
# Out:
# {'Henry Cejudo': '−330', 'Marlon Vera': '+275'}

# %% [markdown]
# #### Saving file:

# %%
data.to_csv(CARDS_PATH + 'darftking_odds_' + get_current_date() + '.csv', index=0)
data.tail(3)
# Out:
#             fighter fighter_odds          opponent opponent_odds
# 27     Leon Edwards         −110   Colby Covington          −110
# 28   Conor McGregor         −110  Michael Chandler          −110
# 29  Islam Makhachev         −285  Charles Oliveira          +240
